# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.6

# %%
import torch
print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU count:", torch.cuda.device_count())
# Out:
# 2.6.0+cu126
# CUDA available: True
# CUDA version: 12.6
# GPU count: 1

# %%
with np.load('datasets/Briareo/splits/test/rgb_test.npz', allow_pickle=True) as data:
    arr = data['arr_0']
    print("Тип:", type(arr))
    print("Форма (shape):", arr.shape)
    print("Тип данных (dtype):", arr.dtype)
    
    # Если это массив объектов, посмотри первый элемент
    if arr.dtype == 'object':
        print("Пример первого элемента:", arr[0])
        print("Тип первого элемента:", type(arr[0]))
        if hasattr(arr[0], 'shape'):
            print("Форма первого элемента:", arr[0].shape)
# Out:
# Тип: <class 'numpy.ndarray'>
# Форма (shape): (288,)
# Тип данных (dtype): object
# ...
